# %%
import os, re, unicodedata, ftfy, pandas as pd
from langchain.document_loaders import PDFMinerLoader
from tqdm.auto import tqdm

def clean_metadata(text: str) -> str:
    text = ftfy.fix_text(text)
    text = unicodedata.normalize("NFC", text)
    text = "".join(ch for ch in text if unicodedata.category(ch)[0] != "C")
    return text

def clean_text(text: str) -> str:
    text = ftfy.fix_text(text)
    text = unicodedata.normalize("NFC", text)
    text = "".join(ch for ch in text if unicodedata.category(ch)[0] != "C")
    return re.sub(r"\s+", " ", text).strip()

def resolve_pdf_path(base_dir, filename):
    return os.path.join(base_dir, "pdf", filename)

df = pd.read_csv("metadata.csv")
# Clean every textual column in-place
for col in [c for c in df.columns if df[c].dtype == "object"]:
    df[col] = df[col].astype(str).map(clean_metadata)

i = 0
records = []
for _, row in tqdm(df.iterrows(), total=len(df), desc="PDF→pages"):
    pdf_path = resolve_pdf_path(row["source_dir"], row["PDF Filename"])
    if not os.path.isfile(pdf_path):
        continue

    fulltext = ""
    for p_idx, page in enumerate(PDFMinerLoader(pdf_path).load(), 1):
        fulltext += page.page_content
    records.append({
        **row.to_dict(),
        "fulltext": clean_text(fulltext)
    })

    i+=1

    if i == 10:
        break
# Out:
# PDF→pages:   0%|          | 9/2504 [00:49<3:47:14,  5.46s/it]

# %%
page_df = pd.DataFrame.from_records(records)

# %%
page_df = page_df.rename(columns= {'Unnamed: 0': "ID"})

# %%
page_df
# Out:
#    ID                                              Title  \
# 0   0  E-kerosene providers call upon the German gove...
# 1   1  E-kerosene providers call upon the German gove...
# 2   2  Industry and NGOs calls for swift adoption of ...
# 3   3                  What Strategic Projects to select
# 4   4  The corporate sector continues to lag behind p...
# 5   5             Mobility policy needs systems thinking
# 6   6             Mobility policy needs systems thinking
# 7   7             Mobility policy needs systems thinking
# 8   8  How EU states can tackle unsustainable biofuel...
# 9   9          Mining waste: time for the EU to clean up
#
#                                              Summary  \
# 0  T&E, EDL, Norsk e-fuel, Arcadia e-fuels, Caphe...
# 1  T&E, EDL, Norsk e-fuel, Arcadia e-fuels, Caphe...
# 2  T&E and three industry associations call on th...
# 3  T&E recommendations on the implementation of t...
# 4  The EU's corporate car market stagnation is ex...
# 5  System thinking is badly needed in mobility po...
# 6  System thinking is badly needed in mobility po...
# 7  System thinking is badly needed in mobility po...
# 8  RED III implementation for Europe's member states
# 9  A new legal analysis makes the case for a revi...
#
#             Publication Date Publication Type  \
# 0  Sep 16, 2024, 12:00:00 AM           Letter
# 1  Sep 16, 2024, 12:00:00 AM           Letter
# 2   Sep 11, 2024, 2:13:00 PM           Letter
# 3   Sep 9, 2024, 11:00:00 AM         Briefing
# 4   Sep 3, 2024, 10:23:00 AM    Press Release
# 5   Sep 3, 2024, 12:00:00 AM          Opinion
# 6   Sep 3, 2024, 12:00:00 AM          Opinion
# 7   Sep 3, 2024, 12:00:00 AM          Opinion
# 8    Sep 2, 2024, 5:00:00 PM         Briefing
# 9  Aug 26, 2024, 12:00:00 AM         Briefing
#
#                                          Article URL  \
# 0  https://www.transportenvironment.org/articles/...
# 1  https://www.transportenvironment.org/articles/...
# 2  https://www.transportenvironment.org/articles/...
# 3  https://www.transportenvironment.org/articles/...
# 4  https://www.transportenvironment.org/articles/...
# 5  https://www.transportenvironment.org/articles/...
# 6  https://www.transportenvironment.org/articles/...
# 7  https://www.transportenvironment.org/articles/...
# 8  https://www.transportenvironment.org/articles/...
# 9  https://www.transportenvironment.org/articles/...
#
#                                     Article Filename  \
# 0  www.transportenvironment.org_articles_e-kerose...
# 1  www.transportenvironment.org_articles_e-kerose...
# 2  www.transportenvironment.org_articles_industry...
# 3  www.transportenvironment.org_articles_what-str...
# 4  www.transportenvironment.org_articles_the-corp...
# 5  www.transportenvironment.org_articles_mobility...
# 6  www.transportenvironment.org_articles_mobility...
# 7  www.transportenvironment.org_articles_mobility...
# 8  www.transportenvironment.org_articles_how-eu-s...
# 9  www.transportenvironment.org_articles_mining-w...
#
#                                              PDF URL  \
# 0  https://www.transportenvironment.org/uploads/f...
# 1  https://www.transportenvironment.org/uploads/f...
# 2  https://www.transportenvironment.org/uploads/f...
# 3  https://www.transportenvironment.org/uploads/f...
# 4  https://www.transportenvironment.org/uploads/f...
# 5  https://mahb.stanford.edu/wp-content/uploads/2...
# 6                   https://docs.iza.org/dp16855.pdf
# 7  https://113.wpcdnnode.com/ariebleijenberg.nl/w...
# 8  https://www.transportenvironment.org/uploads/f...
# 9  https://www.transportenvironment.org/uploads/f...
#
#                                         PDF Filename    office  \
# 0  e_kerosene_providers_call_upon_the_german_gove...  Brussels
# 1  e_kerosene_providers_call_upon_the_german_gove...  Brussels
# 2  industry_and_ngos_calls_for_swift_adoption_of_...  Brussels
# 3  what_strategic_projects_to_select_briefing_wha...  Brussels
# 4  the_corporate_sector_continues_to_lag_behind_p...  Brussels
# 5  mobility_policy_needs_systems_thinking_yale_pu...  Brussels
# 6  mobility_policy_needs_systems_thinking_dp16855...  Brussels
# 7  mobility_policy_needs_systems_thinking_transpo...  Brussels
# 8  how_eu_states_can_tackle_unsustainable_biofuel...  Brussels
# 9  mining_waste_time_for_the_eu_to_clean_up_brief...  Brussels
#
#             source_dir                                           fulltext
# 0  ./scraping/brussels  Open letter: Retaining Germany's national e-ke...
# 1  ./scraping/brussels  Prof. Dr. E. Pache, Domerschulstraße 16, D-970...
# 2  ./scraping/brussels  To: Hungarian Presidency of the Council of the...
# 3  ./scraping/brussels  BRIEFING - September 2024What Strategic Projec...
# 4  ./scraping/brussels  Unveiling Europe's corporatecar problemHow the...
# 5  ./scraping/brussels  DOI: 10.1111/jiec.13084R E S E A R C H A N D A...
# 6  ./scraping/brussels  DISCUSSION PAPER SERIESIZA DP No. 16855Working...
# 7  ./scraping/brussels  Pagina 1 van 16 The transport-urbanisation dia...
# 8  ./scraping/brussels  BRIEFING - September 2024RED III implementatio...
# 9  ./scraping/brussels  BRIEFING - AUGUST 2024Mining waste: time for t...

# %%
page_df.to_parquet("output/metadata_with_fulltext.parquet", index=False)
page_df.to_csv("output/metadata_with_fulltext.csv", index=False)

# %%
import hashlib, os, json, faiss, pandas as pd
from tqdm.auto import tqdm
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter

### CONFIG ###
PARQUET_PATH   = "output/metadata_with_fulltext.parquet"           # produced in the previous step
INDEX_OUT      = "output/docs.index"
MAP_OUT        = "output/faiss_mapping.parquet"
MODEL_NAME     = "sentence-transformers/all-MiniLM-L6-v2"
CHUNK_SIZE     = 1024                       # characters
CHUNK_OVERLAP  = 64
################

# 1. Load pages
pages = pd.read_parquet(PARQUET_PATH)

# 2. Prepare splitter & embedder
splitter  = RecursiveCharacterTextSplitter(chunk_size=CHUNK_SIZE,
                                           chunk_overlap=CHUNK_OVERLAP,
                                            add_start_index  = True)        # <-- NEW)
embedder  = HuggingFaceEmbeddings(model_name=MODEL_NAME)

# %%
# 3. Build FAISS index progressively
print(embedder.embed_query("test"))
# Out:
# [0.01157346274703741, 0.0251361932605505, -0.03670189157128334, 0.059324879199266434, -0.0071490490809082985, -0.04119426757097244, 0.07708740234375, 0.03744257986545563, 0.012449024245142937, -0.00611764844506979, 0.017034266144037247, -0.07701534777879715, -0.00039417133666574955, 0.027909060940146446, -0.015989137813448906, -0.06827525049448013, 0.008884693495929241, -0.020280746743083, -0.08035992830991745, -0.013074045069515705, -0.04109999164938927, -0.02589806169271469, -0.026538675650954247, 0.03305229917168617, -0.022079166024923325, 0.021046113222837448, -0.05792200192809105, 0.03294878453016281, 0.02970738708972931, -0.06224842742085457, 0.03878801316022873, 0.031990695744752884, 0.015330800786614418, 0.0453069694340229, 0.05314943194389343, 0.013360688462853432, 0.04122495651245117, 0.028142889961600304, 0.019398432224988937, -0.003252344438806176, -0.0036123283207416534, -0.1428602635860443, 0.03807120397686958, -0.010916150175035, 0.026094019412994385, 0.04136991873383522, -0.016015777364373207, 0.05356009304523468, -0.05685943737626076, 0.012246795929968357, -0.034996580332517624, -0.039754170924425125, -0.04614297300577164, -0.03911235183477402, -0.018003642559051514, 0.021634291857481003, -0.006461363285779953, -0.026569483801722527, 0.048728782683610916, 0.043400585651397705, 0.046200066804885864, -0.03447899967432022, -0.024219270795583725, 0.055649079382419586, 0.024624409154057503, 0.019485559314489365, 0.011352802626788616, -0.025762291625142097, -0.032244499772787094, -0.03265216946601868, -0.014595926739275455, 0.014690374955534935, 0.010304559022188187, 0.0740797147154808, 0.08006179332733154, -0.004143542610108852, 0.002714266534894705, -0.07674670964479446, 0.058815304189920425, -0.0048391674645245075, -0.08736330270767212, -0.046461932361125946, -0.03962540626525879, 0.05249391868710518, 0.02480142004787922, 0.08080150187015533, 0.11981366574764252, 0.03177144378423691, -0.11397235095500946, 0.010673855431377888, 0.01972380094230175, 0.03871830925345421, -0.03454234451055527, -0.006243118550628424, -0.04255080223083496, 0.022628575563430786, 0.008293665945529938, -0.01944361813366413, -0.023251064121723175, 0.24533763527870178, 0.049442190676927567, 0.029147407039999962, -0.005753710865974426, -0.020419562235474586, -0.0776115283370018, -0.042979273945093155, 0.0004302548186387867, -0.06692591309547424, 0.0707603469491005, 0.006507000885903835, -0.058445341885089874, -0.005057346075773239, 0.030943766236305237, 0.02757958509027958, 0.027111215516924858, -0.0681861937046051, -0.0657687559723854, 0.05907768756151199, -0.031894128769636154, 0.04060604050755501, 0.0571017824113369, 0.006903534755110741, 0.006207624915987253, -0.013271454721689224, 0.031240426003932953, -0.04029695689678192, 0.07085210829973221, -4.8462726409304475e-33, 0.0219343900680542, -0.10270480066537857, 0.05621322616934776, 0.09758371114730835, -0.05268486589193344, 0.019097693264484406, -0.010507444851100445, 0.07035724073648453, -0.009123307652771473, 0.05957065150141716, 0.009338605217635632, -0.015523049980401993, -0.023274047300219536, 0.023976819589734077, 0.1020885482430458, 0.09320349991321564, -0.03313611075282097, 0.011721625924110413, -0.06560061126947403, 0.031464796513319016, -0.02380792237818241, -0.04873908683657646, 0.012257928028702736, -0.04001419246196747, -0.07650820165872574, -0.0355532169342041, -0.0013622005935758352, -0.016429198905825615, 0.016882453113794327, -0.00037489295937120914, -0.05272500962018967, 0.029880965128540993, -0.07291100919246674, 0.0691225603222847, -0.017607951536774635, -0.005510312505066395, 0.012954636476933956, -0.02270195074379444, 0.026741303503513336, -0.02584579400718212, -0.04020208492875099, -0.013495107181370258, 0.0007997855427674949, 0.028601275756955147, 0.03194253519177437, -0.03160709887742996, -0.02954988367855549, -0.020251261070370674, 0.04817776754498482, -0.0013076246250420809, -0.01374721433967352, 0.020030159503221512, -0.06870562583208084, -0.021960768848657608 ...

# %%
from langchain.schema import Document   # if you need an empty shell
import numpy as np
dim    = len(embedder.embed_query("test"))   # vector length
index  = faiss.IndexFlatL2(dim)                  # no-frills L2 index
mapping_rows = []
seen_hashes  = set()

vec_id = 0
for _, row in tqdm(pages.iterrows(), total=len(pages), desc="chunk→embed"):
    page_text = Document(page_content=row["fulltext"], metadata={})
    # 3.1 Split page into overlapping chunks
    chunks = splitter.split_documents([page_text])

    for doc in chunks:

        chunk     = doc.page_content
        start     = doc.metadata["start_index"]
        end       = start + len(chunk)

        # 3.2 Deduplicate by content hash
        h = hashlib.sha256(chunk.encode("utf-8")).hexdigest()
        if h in seen_hashes:          # already embedded identical text
            continue
        seen_hashes.add(h)


        # 3.3 Embed & add to FAISS
        vec = embedder.embed_documents([chunk])
        index.add(np.array(vec))

        # 3.4 Remember how to find this chunk again
        mapping_rows.append({
            "vector_id"  : vec_id,
            "doc_id"     : row["ID"],   # or your own identifier
            "start_char" : start,
            "end_char"   : end
        })
        vec_id += 1

# 4. Persist
faiss.write_index(index, INDEX_OUT)
pd.DataFrame(mapping_rows).to_parquet(MAP_OUT, index=False)

print(f"✅  Index with {index.ntotal:,} unique chunks written to {INDEX_OUT}")
print(f"✅  Mapping file with {len(mapping_rows):,} rows written to {MAP_OUT}")
# Out:
# chunk→embed:   0%|          | 0/10 [00:00<?, ?it/s]
# chunk→embed: 100%|██████████| 10/10 [00:40<00:00,  4.10s/it]
# ✅  Index with 340 unique chunks written to output/docs.index
# ✅  Mapping file with 340 rows written to output/faiss_mapping.parquet

# %%
# ── 0.  pip installs ──────────────────────────────────────────────
# pip install -qU faiss-cpu pandas pyarrow langchain sentence-transformers

# ── 1.  imports & paths ───────────────────────────────────────────
import pandas as pd
from pathlib import Path
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS               # wrapper


# ── 2.  load everything back ──────────────────────────────────────
embeddings = HuggingFaceEmbeddings(model_name=MODEL_NAME)

vectorstore  = FAISS.load_local(INDEX_OUT, embeddings)
index       = vectorstore.index                              # native faiss.Index

mapping = pd.read_parquet(MAP_OUT).set_index("vector_id")
pages   = (pd.read_parquet(PARQUET_PATH)
             .set_index("ID")                    # “ID” column in your mapping
           )

# ── 3.  helper: turn query → top-k chunks  ────────────────────────
def search(query: str, k: int = 5):
    q_vec = embeddings.embed_query(query)
    D, I  = index.search(q_vec, k)               # I = [vec_ids],  D = L2 distances

    # gather rows that tell us where each vector came from
    hits = mapping.loc[I[0]].copy()
    hits["score"] = D[0]

    # slice the original full-text back into the exact chunk
    def extract_chunk(row):
        text = pages.loc[row["doc_id"], "fulltext"]
        return text[row["start_char"] : row["end_char"]]

    hits["chunk_text"] = hits.apply(extract_chunk, axis=1)
    return hits[["score", "doc_id", "chunk_text"]]

# ── 4.  example run  ───────────────────────────────────────────────
df = search("hydrogen refuelling stations in Belgium", k=3)
print(df.to_markdown(index=False, tablefmt="github"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 37
#      34     return hits[["score", "doc_id", "chunk_text"]]
#      36 # ── 4.  example run  ───────────────────────────────────────────────
# ---> 37 df = search("hydrogen refuelling stations in Belgium", k=3)
#      38 print(df.to_markdown(index=False, tablefmt="github"))
#
# Cell In[31], line 22, in search(query, k)
#      20 def search(query: str, k: int = 5):
#      21     q_vec = embeddings.embed_query(query)
# ---> 22     D, I  = index.search(q_vec, k)               # I = [vec_ids],  D = L2 distances
#      24     # gather rows that tell us where each vector came from
#      25     hits = mapping.loc[I[0]].copy()
#
# File c:\Users\TE\Documents\t-and-e-webscraper\.venv\Lib\site-packages\faiss\class_wrappers.py:327, in handle_Index.<locals>.replacement_search(self, x, k, params, D, I)
#     300 def replacement_search(self, x, k, *, params=None, D=None, I=None):
#     301     """Find the k nearest neighbors of the set of vectors x in the index.
#     302
#     303     Parameters
#    (...)    324         When not enough results are found, the label is set to -1
#     325     """
# --> 327     n, d = x.shape
#     328     x = np.ascontiguousarray(x, dtype='float32')
#     329     assert d == self.d
#
# AttributeError: 'list' object has no attribute 'shape'
